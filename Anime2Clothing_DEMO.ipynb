# %% [markdown]
# # Anime2Clothing
# Pytorch official implementation of **Anime to Real Clothing: Cosplay Costume Generation via Image-to-Image Translation**.
# ![purpose_of_paper.png](data:image/png;base64,...)

# %% [markdown]
# ## Prerequisites
# - Anaconda 3
# - Python 3
# - PyTorch
# - CPU or NVIDIA GPU + CUDA CuDNN
#
# ## Note
# We recommend using an anime character image with a simple background as the input image.

# %%
# !git clone https://github.com/tan5o/anime2clothing
# Out:
# Cloning into 'anime2clothing'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 68 (delta 22), reused 56 (delta 14), pack-reused 0
# Unpacking objects: 100% (68/68), done.

# %%
cd anime2clothing/
# Out:
# /content/anime2clothing

# %%
# !mkdir input_dir
# !mkdir output_dir

# %% [markdown]
# # DEMO

# %%
from google.colab import files
import shutil

files = files.upload()
file_name = list(files.keys())[0]

shutil.move(file_name, 'input_dir/')
# Out:
#      <input type="file" id="files-f87a638c-f461-40ec-a2a4-c101a3e1cf19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f87a638c-f461-40ec-a2a4-c101a3e1cf19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 0.png to 0.png
# 'input_dir/0.png'

# %%
# !python test.py --model_path models/pretrained_unet_20200122.pth --input_dir input_dir/ --output_dir output_dir/
# Out:
# Namespace(input_dir='input_dir/', model_path='models/pretrained_unet_20200122.pth', output_dir='output_dir/')
# found 1 files
# 0/1

# %%
from IPython.display import Image, display_png
display_png(Image('output_dir/' + file_name))

# %%
from google.colab import files
import shutil

files = files.upload()
file_name = list(files.keys())[0]

shutil.move(file_name, 'input_dir/')
# Out:
#      <input type="file" id="files-7135462a-aef2-41b8-82a8-59c9d7eac05b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7135462a-aef2-41b8-82a8-59c9d7eac05b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1.png to 1.png
# 'input_dir/1.png'

# %%
# !python test.py --model_path models/pretrained_unet_20200122.pth --input_dir input_dir/ --output_dir output_dir/
# Out:
# Namespace(input_dir='input_dir/', model_path='models/pretrained_unet_20200122.pth', output_dir='output_dir/')
# found 2 files
# 0/2
# 1/2

# %%
from IPython.display import Image, display_png
display_png(Image('output_dir/' + file_name))

# %%
from google.colab import files
import shutil

files = files.upload()
file_name = list(files.keys())[0]

shutil.move(file_name, 'input_dir/')
# Out:
#      <input type="file" id="files-f71e1dc5-4eae-4544-abb6-4768a7e6dc73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f71e1dc5-4eae-4544-abb6-4768a7e6dc73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.png to 2.png
# 'input_dir/2.png'

# %%
# !python test.py --model_path models/pretrained_unet_20200122.pth --input_dir input_dir/ --output_dir output_dir/
# Out:
# Namespace(input_dir='input_dir/', model_path='models/pretrained_unet_20200122.pth', output_dir='output_dir/')
# found 3 files
# 0/3
# 1/3
# 2/3

# %%
from IPython.display import Image, display_png
display_png(Image('output_dir/' + file_name))

# %%
from google.colab import files
import shutil

files = files.upload()
file_name = list(files.keys())[0]

shutil.move(file_name, 'input_dir/')
# Out:
#      <input type="file" id="files-035799c6-624f-48f7-8cda-e74e65722f71" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-035799c6-624f-48f7-8cda-e74e65722f71">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 4.png to 4.png
# 'input_dir/4.png'

# %%
# !python test.py --model_path models/pretrained_unet_20200122.pth --input_dir input_dir/ --output_dir output_dir/
# Out:
# Namespace(input_dir='input_dir/', model_path='models/pretrained_unet_20200122.pth', output_dir='output_dir/')
# found 4 files
# 0/4
# 1/4
# 2/4
# 3/4

# %%
from IPython.display import Image, display_png
display_png(Image('output_dir/' + file_name))

# %%
from google.colab import files
import shutil

files = files.upload()
file_name = list(files.keys())[0]

shutil.move(file_name, 'input_dir/')
# Out:
#      <input type="file" id="files-dd7fa6d5-55d4-4974-846e-a1c776623928" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd7fa6d5-55d4-4974-846e-a1c776623928">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3.png to 3.png
# 'input_dir/3.png'

# %%
# !python test.py --model_path models/pretrained_unet_20200122.pth --input_dir input_dir/ --output_dir output_dir/
# Out:
# Namespace(input_dir='input_dir/', model_path='models/pretrained_unet_20200122.pth', output_dir='output_dir/')
# found 5 files
# 0/5
# 1/5
# 2/5
# 3/5
# 4/5

# %%
from IPython.display import Image, display_png
display_png(Image('output_dir/' + file_name))
